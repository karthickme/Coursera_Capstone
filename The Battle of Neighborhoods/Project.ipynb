# %% [markdown]
# <h4>Importing all the required packges

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

import numpy as np # library to handle data in a vectorized manner

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#!pip install geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!pip install folium
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
#downloading required packages
# !wget 'https://data.london.gov.uk/download/london-borough-profiles/c1693b82-68b1-44ee-beb2-3decf17dc1f8/london-borough-profiles.csv'
# Out:
# --2020-01-18 13:23:16--  https://data.london.gov.uk/download/london-borough-profiles/c1693b82-68b1-44ee-beb2-3decf17dc1f8/london-borough-profiles.csv
# Resolving data.london.gov.uk (data.london.gov.uk)... 2600:9000:21f8:d800:1b:a243:2080:93a1, 2600:9000:21f8:1800:1b:a243:2080:93a1, 2600:9000:21f8:a000:1b:a243:2080:93a1, ...
# Connecting to data.london.gov.uk (data.london.gov.uk)|2600:9000:21f8:d800:1b:a243:2080:93a1|:443... failed: Connection timed out.
# Connecting to data.london.gov.uk (data.london.gov.uk)|2600:9000:21f8:1800:1b:a243:2080:93a1|:443... failed: Connection timed out.
# Connecting to data.london.gov.uk (data.london.gov.uk)|2600:9000:21f8:a000:1b:a243:2080:93a1|:443... failed: Connection timed out.
# Connecting to data.london.gov.uk (data.london.gov.uk)|2600:9000:21f8:1e00:1b:a243:2080:93a1|:443... failed: Connection timed out.
# Connecting to data.london.gov.uk (data.london.gov.uk)|2600:9000:21f8:ee00:1b:a243:2080:93a1|:443... failed: Connection timed out.
# ...

# %%
#reading the data
df_london = pd.read_csv('london-borough-profiles.csv',encoding='latin1')

# %%
df_london
# Out:
#          Code               Area_name Inner/_Outer_London  \
# 0   E09000001          City of London        Inner London
# 1   E09000002    Barking and Dagenham        Outer London
# 2   E09000003                  Barnet        Outer London
# 3   E09000004                  Bexley        Outer London
# 4   E09000005                   Brent        Outer London
# 5   E09000006                 Bromley        Outer London
# 6   E09000007                  Camden        Inner London
# 7   E09000008                 Croydon        Outer London
# 8   E09000009                  Ealing        Outer London
# 9   E09000010                 Enfield        Outer London
# 10  E09000011               Greenwich        Outer London
# 11  E09000012                 Hackney        Inner London
# 12  E09000013  Hammersmith and Fulham        Inner London
# 13  E09000014                Haringey        Inner London
# 14  E09000015                  Harrow        Outer London
# ...

# %%
df_london[['Area_name', 'Inner/_Outer_London','Number_of_active_businesses,_2015',
       'Two-year_business_survival_rates_(started_in_2013)']]
# Out:
#                  Area_name Inner/_Outer_London  \
# 0           City of London        Inner London
# 1     Barking and Dagenham        Outer London
# 2                   Barnet        Outer London
# 3                   Bexley        Outer London
# 4                    Brent        Outer London
# 5                  Bromley        Outer London
# 6                   Camden        Inner London
# 7                  Croydon        Outer London
# 8                   Ealing        Outer London
# 9                  Enfield        Outer London
# 10               Greenwich        Outer London
# 11                 Hackney        Inner London
# 12  Hammersmith and Fulham        Inner London
# 13                Haringey        Inner London
# 14                  Harrow        Outer London
# 15                Havering        Outer London
# 16              Hillingdon        Outer London
# 17                Hounslow        Outer London
# 18               Islington        Inner London
# ...

# %%
df = df_london[['Area_name', 'Inner/_Outer_London','Number_of_active_businesses,_2015',
       'Two-year_business_survival_rates_(started_in_2013)']][df_london['Inner/_Outer_London']=='Inner London']
df
# Out:
#                  Area_name Inner/_Outer_London  \
# 0           City of London        Inner London
# 6                   Camden        Inner London
# 11                 Hackney        Inner London
# 12  Hammersmith and Fulham        Inner London
# 13                Haringey        Inner London
# 18               Islington        Inner London
# 19  Kensington and Chelsea        Inner London
# 21                 Lambeth        Inner London
# 22                Lewisham        Inner London
# 24                  Newham        Inner London
# 27               Southwark        Inner London
# 29           Tower Hamlets        Inner London
# 31              Wandsworth        Inner London
# 32             Westminster        Inner London
#
#     Number_of_active_businesses,_2015  \
# 0                               26130
# 6                               31385
# 11                              18510
# 12                              14095
# 13                              12675
# ...

# %%
df.drop('Inner/_Outer_London',axis=1,inplace=True)
df
# Out:
#                  Area_name  Number_of_active_businesses,_2015  \
# 0           City of London                              26130
# 6                   Camden                              31385
# 11                 Hackney                              18510
# 12  Hammersmith and Fulham                              14095
# 13                Haringey                              12675
# 18               Islington                              22110
# 19  Kensington and Chelsea                              14350
# 21                 Lambeth                              17280
# 22                Lewisham                              10405
# 24                  Newham                              11055
# 27               Southwark                              17120
# 29           Tower Hamlets                              18390
# 31              Wandsworth                              18695
# 32             Westminster                              55385
#
# ...

# %%
#Wikipdia data to get the Coordiantes
wikipage = 'https://en.wikipedia.org/wiki/List_of_London_boroughs'
pagedump = pd.read_html(wikipage)
london_boroughs_coorinates =pagedump[0]

# %%
london_boroughs_coorinates
# Out:
#                             Borough     Inner Status  \
# 0     Barking and Dagenham [note 1]       NaN    NaN
# 1                            Barnet       NaN    NaN
# 2                            Bexley       NaN    NaN
# 3                             Brent       NaN    NaN
# 4                           Bromley       NaN    NaN
# 5                            Camden       NaN    NaN
# 6                           Croydon       NaN    NaN
# 7                            Ealing       NaN    NaN
# 8                           Enfield       NaN    NaN
# 9                Greenwich [note 2]  [note 3]  Royal
# 10                          Hackney       NaN    NaN
# 11  Hammersmith and Fulham [note 4]       NaN    NaN
# 12                         Haringey  [note 3]    NaN
# 13                           Harrow       NaN    NaN
# 14                         Havering       NaN    NaN
# 15                       Hillingdon       NaN    NaN
# 16                         Hounslow       NaN    NaN
# ...

# %%
#Cleaning the Column names in the Dfs and matching them
df.columns = ['Borough', 'Number_of_active_businesses','Two-year_business_survival_rates']
#Cleanup
london_boroughs_coorinates["Borough"]= london_boroughs_coorinates["Borough"].str.replace('[]', "")
# london_boroughs_coorinates["Borough"]= london_boroughs_coorinates["Borough"].str.replace(r" [note 2]", "")
# london_boroughs_coorinates["Borough"]= london_boroughs_coorinates["Borough"].str.replace(r" [note 3]", "")
# london_boroughs_coorinates["Borough"]= london_boroughs_coorinates["Borough"].str.replace(r" [note 4]", "")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-40-7513ec82dc6f> in <module>
#       2 df.columns = ['Borough', 'Number_of_active_businesses','Two-year_business_survival_rates']
#       3 #Cleanup
# ----> 4 london_boroughs_coorinates["Borough"]= london_boroughs_coorinates["Borough"].str.replace('[]', "")
#       5 # london_boroughs_coorinates["Borough"]= london_boroughs_coorinates["Borough"].str.replace(r" [note 2]", "")
#       6 # london_boroughs_coorinates["Borough"]= london_boroughs_coorinates["Borough"].str.replace(r" [note 3]", "")
#
# ~/.local/share/virtualenvs/all-iT6o4PfX/lib/python3.6/site-packages/pandas/core/strings.py in wrapper(self, *args, **kwargs)
#    1841                 )
#    1842                 raise TypeError(msg)
# -> 1843             return func(self, *args, **kwargs)
#    1844
#    1845         wrapper.__name__ = func_name
#
# ...

# %%
london_boroughs_coorinates
# Out:
#                       Borough     Inner Status  \
# 0     Barking and Dagenham []       NaN    NaN
# 1                      Barnet       NaN    NaN
# 2                      Bexley       NaN    NaN
# 3                       Brent       NaN    NaN
# 4                     Bromley       NaN    NaN
# 5                      Camden       NaN    NaN
# 6                     Croydon       NaN    NaN
# 7                      Ealing       NaN    NaN
# 8                     Enfield       NaN    NaN
# 9                Greenwich []  [note 3]  Royal
# 10                    Hackney       NaN    NaN
# 11  Hammersmith and Fulham []       NaN    NaN
# 12                   Haringey  [note 3]    NaN
# 13                     Harrow       NaN    NaN
# 14                   Havering       NaN    NaN
# 15                 Hillingdon       NaN    NaN
# 16                   Hounslow       NaN    NaN
# 17                  Islington       NaN    NaN
# 18     Kensington and Chelsea       NaN  Royal
# ...

# %%
df.columns
# Out:
# Index(['Borough', 'Number_of_active_businesses',
#        'Two-year_business_survival_rates'],
#       dtype='object')

# %%
df_london = pd.merge(df,london_boroughs_coorinates[['Borough','Population (2013 est)[1]','Co-ordinates']], on='Borough',how='left')

# %%
df_london
# Out:
#                    Borough  Number_of_active_businesses  \
# 0           City of London                        26130
# 1                   Camden                        31385
# 2                  Hackney                        18510
# 3   Hammersmith and Fulham                        14095
# 4                 Haringey                        12675
# 5                Islington                        22110
# 6   Kensington and Chelsea                        14350
# 7                  Lambeth                        17280
# 8                 Lewisham                        10405
# 9                   Newham                        11055
# 10               Southwark                        17120
# 11           Tower Hamlets                        18390
# 12              Wandsworth                        18695
# 13             Westminster                        55385
#
#     Two-year_business_survival_rates  Population (2013 est)[1]  \
# ...

# %%
#Not using tghis

address = 'Islington'

geolocator = Nominatim(user_agent="Jupyter")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 51.5384287, -0.0999051.

# %%
#Not using tghis
map_NewYork = folium.Map(location=[latitude, longitude], zoom_start=15)
map_NewYork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
london_boroughs_coorinates
# Out:
#                           Borough     Inner Status  \
# 0     Barking and Dagenham [note]       NaN    NaN
# 1                          Barnet       NaN    NaN
# 2                          Bexley       NaN    NaN
# 3                           Brent       NaN    NaN
# 4                         Bromley       NaN    NaN
# 5                          Camden       NaN    NaN
# 6                         Croydon       NaN    NaN
# 7                          Ealing       NaN    NaN
# 8                         Enfield       NaN    NaN
# 9                Greenwich [note]  [note 3]  Royal
# 10                        Hackney       NaN    NaN
# 11  Hammersmith and Fulham [note]       NaN    NaN
# 12                       Haringey  [note 3]    NaN
# 13                         Harrow       NaN    NaN
# 14                       Havering       NaN    NaN
# 15                     Hillingdon       NaN    NaN
# 16                       Hounslow       NaN    NaN
# ...
